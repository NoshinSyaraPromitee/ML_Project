# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

DATA_PATH = '/content/Resume.csv'

df = pd.read_csv(DATA_PATH)
df = df[['ID', 'Resume_str', 'Category']]

print(df.shape)
df.head()
# Out:
# (553, 3)
#          ID                                         Resume_str Category
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...       HR
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...       HR
# 2  33176873           HR DIRECTOR       Summary      Over 2...       HR
# 3  27018550           HR SPECIALIST       Summary    Dedica...       HR
# 4  17812897           HR MANAGER         Skill Highlights  ...       HR

# %%
print(df['Category'].value_counts())
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Category
# INFORMATION-TECHNOLOGY    120
# ADVOCATE                  113
# HR                        110
# DESIGNER                  107
# TEACHER                   102
# Name: count, dtype: int64
#
# Missing values:
#  ID            0
# Resume_str    0
# Category      1
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, f1_score

def get_split(X, y, stratify=None, test_size=0.2, seed=42):
    return train_test_split(X, y, test_size=test_size, stratify=stratify, random_state=seed)

def regression_metrics(y_true, y_pred):
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    mae = mean_absolute_error(y_true, y_pred)
    return {"RMSE": round(rmse, 3), "MAE": round(mae, 3)}

def classification_metrics(y_true, y_pred):
    return {"macro_F1": round(f1_score(y_true, y_pred, average="macro"), 3)}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    return {
        "RMSE": round(rmse, 3),
        "MAE": round(mae, 3)
    }

# %%
harness_code = '''
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, f1_score

def get_split(X, y, stratify=None, test_size=0.2, seed=42):
    return train_test_split(X, y, test_size=test_size, stratify=stratify, random_state=seed)

def regression_metrics(y_true, y_pred):
    rmse = (mean_squared_error(y_true, y_pred)) ** 0.5
    mae = mean_absolute_error(y_true, y_pred)
    return {"RMSE": round(float(rmse), 3), "MAE": round(float(mae), 3)}

def classification_metrics(y_true, y_pred):
    return {"macro_F1": round(f1_score(y_true, y_pred, average="macro"), 3)}
'''
with open('/content/drive/MyDrive/SkillSync_Project/eval_utils.py', 'w') as f:
    f.write(harness_code)
print("Saved — share Drive link with P1 and P2.")
# Out:
# Saved — share Drive link with P1 and P2.

# %%
Waiting for the person 2 's quality score.csv file '

# %%
quality_df = pd.read_csv('/content/drive/MyDrive/SkillSync_Project/data/quality_scores.csv')
df = df.merge(quality_df[['ID', 'quality_score']], on='ID', how='inner')
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2491/1382315706.py in <cell line: 0>()
# ----> 1 quality_df = pd.read_csv('/content/drive/MyDrive/SkillSync_Project/data/quality_scores.csv')
#       2 df = df.merge(quality_df[['ID', 'quality_score']], on='ID', how='inner')
#       3 print(df.shape)
#
# ...
